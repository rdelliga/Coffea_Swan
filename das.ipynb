# %%
# Using readlines()
file_r = open('files_txt/WJetsToLNu.txt', 'r')
Lines = file_r.readlines()
file_r.close()
file_r1 = open('files_txt/WJetsToLNu_HT-70To100.txt', 'r')
Lines_1 = file_r1.readlines()
file_r1.close()
file_r2 = open('files_txt/WJetsToLNu_HT-100To200.txt', 'r')
Lines_2 = file_r2.readlines()
file_r2.close()
file_r3 = open('files_txt/WJetsToLNu_HT-200To400.txt', 'r')
Lines_3 = file_r3.readlines()
file_r3.close()
file_r4 = open('files_txt/WJetsToLNu_HT-400To600.txt', 'r')
Lines_4 = file_r4.readlines()
file_r4.close()
file_r4_ex = open('files_txt/WJetsToLNu_HT-400To600_ex.txt', 'r')
Lines_4_ex = file_r4_ex.readlines()
file_r4_ex.close()
file_r5 = open('files_txt/WJetsToLNu_HT-600To800.txt', 'r')
Lines_5 = file_r5.readlines()
file_r5.close()
file_r5_ex = open('files_txt/WJetsToLNu_HT-600To800_ex.txt', 'r')
Lines_5_ex = file_r5_ex.readlines()
file_r5_ex.close()
file_r6 = open('files_txt/WJetsToLNu_HT-800To1200.txt', 'r')
Lines_6 = file_r6.readlines()
file_r6.close()
file_r6_ex = open('files_txt/WJetsToLNu_HT-800To1200_ex.txt', 'r')
Lines_6_ex = file_r6_ex.readlines()
file_r6_ex.close()
file_r7 = open('files_txt/WJetsToLNu_HT-1200To2500.txt', 'r')
Lines_7 = file_r7.readlines()
file_r7.close()
file_r7_ex = open('files_txt/WJetsToLNu_HT-1200To2500_ex.txt', 'r')
Lines_7_ex = file_r7_ex.readlines()
file_r7_ex.close()
file_r8 = open('files_txt/WJetsToLNu_HT-2500ToInf.txt', 'r')
Lines_8 = file_r8.readlines()
file_r8.close()
 
# writing to file
file_w = open('fileset.json', 'w')
file_w.write('{\n\t')
file_w.write('"sig_WWjj_4f_EWK": [\n\t\t"WPHADWMLEPjj_4f_EWK.root",\n\t\t"WPLEPWMHADjj_4f_EWK.root"\n\t],\n\t')

# Strips the newline character
count = 0
file_w.write('"bkg_WJets": [\n')
for line in Lines:
    count += 1
    if count < len(Lines):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line.strip()))
    elif count == len(Lines):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line.strip()))
file_w.write("\t],\n")

count_1 = 0
file_w.write('"bkg_WJets_70To100": [\n')
for line_1 in Lines_1:
    count_1 += 1
    if count_1 < len(Lines_1):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_1.strip()))
    elif count_1 == len(Lines_1):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_1.strip()))
file_w.write("\t],\n")

count_2 = 0
file_w.write('\t"bkg_WJets_100To200": [\n')
for line_2 in Lines_2:
    count_2 += 1
    if count_2 < len(Lines_2):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_2.strip()))
    elif count_2 == len(Lines_2):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_2.strip()))
file_w.write("\t],\n")

count_3 = 0
file_w.write('\t"bkg_WJets_200To400": [\n')
for line_3 in Lines_3:
    count_3 += 1
    if count_3 < len(Lines_3):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_3.strip()))
    elif count_3 == len(Lines_3):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_3.strip()))
file_w.write("\t],\n")

count_4 = 0
file_w.write('\t"bkg_WJets_400To600": [\n')
for line_4 in Lines_4:
    count_4 += 1
    file_w.write('\t\t"/eos/cms{}",\n'.format(line_4.strip()))
count_4_ex = 0
for line_4_ex in Lines_4_ex:
    count_4_ex += 1
    if count_4_ex < len(Lines_4_ex):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_4_ex.strip()))
    elif count_4_ex == len(Lines_4_ex):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_4_ex.strip()))
file_w.write("\t],\n")

count_5 = 0
file_w.write('\t"bkg_WJets_600To800": [\n')
for line_5 in Lines_5:
    count_5 += 1
    file_w.write('\t\t"/eos/cms{}",\n'.format(line_5.strip()))
count_5_ex = 0
for line_5_ex in Lines_5_ex:
    count_5_ex += 1
    if count_5_ex < len(Lines_5_ex):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_5_ex.strip()))
    elif count_5_ex == len(Lines_5_ex):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_5_ex.strip()))
file_w.write("\t],\n")

count_6 = 0
file_w.write('\t"bkg_WJets_800To1200": [\n')
for line_6 in Lines_6:
    count_6 += 1
    file_w.write('\t\t"/eos/cms{}",\n'.format(line_6.strip()))
count_6_ex = 0
for line_6_ex in Lines_6_ex:
    count_6_ex += 1
    if count_6_ex < len(Lines_6_ex):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_6_ex.strip()))
    elif count_6_ex == len(Lines_6_ex):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_6_ex.strip()))
file_w.write("\t],\n")

count_7 = 0
file_w.write('\t"bkg_WJets_1200To2500": [\n')
for line_7 in Lines_7:
    count_7 += 1
    file_w.write('\t\t"/eos/cms{}",\n'.format(line_7.strip()))
count_7_ex = 0
for line_7_ex in Lines_7_ex:
    count_7_ex += 1
    if count_7_ex < len(Lines_7_ex):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_7_ex.strip()))
    elif count_7_ex == len(Lines_7_ex):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_7_ex.strip()))
file_w.write("\t],\n")

count_8 = 0
file_w.write('\t"bkg_WJets_2500ToInf": [\n')
for line_8 in Lines_8:
    count_8 += 1
    if count_8 < len(Lines_8):
        file_w.write('\t\t"/eos/cms{}",\n'.format(line_8.strip()))
    elif count_8 == len(Lines_8):
        file_w.write('\t\t"/eos/cms{}"\n'.format(line_8.strip()))
file_w.write("\t]\n}")


file_w.close()
